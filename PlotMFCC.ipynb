# %%
from features import mfcc
from features import logfbank
import scipy.io.wavfile as wav
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2


(rate,sig) = wav.read("file.wav")
mfcc_feat = mfcc(sig,rate)
mfcc_feat = logfbank(sig,rate)

# %%
mMin = mfcc_feat.min()
mMax = mfcc_feat.max()
mfcc_feat -= mMin
mfcc_feat *= 255/mfcc_feat.max()

# %%
import imutils

print mfcc_feat.min(), mfcc_feat.max(), mfcc_feat.mean()
plt.imshow(mfcc_feat)
# Out:
# 0.0 255.0 173.109896514

# %%
cv2.imshow("win", np.array(mfcc_feat,np.uint8))
cv2.waitKey(0)
# Out:
# 113
